# %% [markdown]
# <a href="https://colab.research.google.com/github/blackdragon18/fmml/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-28 14:00:58--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   166MB/s    in 0.4s
#
# 2023-05-28 14:00:59 (166 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10687   1206.6845v1  Nonparametric Bayesian approaches to clusterin...  stat
# 39282  1507.08861v1  High user interaction capability of mobile dev...    cs
# 16687  1705.01042v1  This paper introduces a new model that uses na...    cs
# 22817  1707.06626v2  We propose a simple algorithm to train stochas...  stat
# 5198    1111.5479v2  The graphical lasso \citep{FHT2007a} is an alg...  stat
# ...             ...                                                ...   ...
# 2277   1712.09327v1  Deep Neural Networks are built to generalize o...    cs
# 5061   1801.05372v1  Feature engineering is one of the most importa...    cs
# 6011   1605.09196v3  We propose a novel methodology, forest floor, ...  stat
# 30612  1712.07732v1  Visual recognition under adverse conditions is...    cs
# 30656  1712.09448v1  While the basic laws of Newtonian mechanics ar...    cs
#
#                                                    title  year  \
# 10687  Gibbs Sampling for (Coupled) Infinite Mixture ...  2012
# 39282              Mobile Multi-View Object Image Search  2015
# 16687     Entity Linking with people entity on Wikipedia  2017
# 22817  Learning to Draw Samples with Amortized Stein ...  2017
# 5198   The Graphical Lasso: New Insights and Alternat...  2011
# ...                                                  ...   ...
# 2277   Building Robust Deep Neural Networks for Road ...  2017
# 5061               Learning Features For Relational Data  2018
# 6011       Forest Floor Visualizations of Random Forests  2016
# 30612  Enhance Visual Recognition under Adverse Condi...  2017
# 30656  Taking Visual Motion Prediction To New Heightf...  2017
#
#                                                 keywords
# 10687  [nonparametric, approaches, clustering, inform...
# 39282  [interaction, capability, different, different...
# 16687  [introduces, recognition, coreference, resolut...
# 22817  [algorithm, stochastic, distributions, probabi...
# 5198   [graphical, algorithm, structure, undirected, ...
# ...                                                  ...
# 2277   [generalize, techniques, regularization, consi...
# 5061   [engineering, important, automation, relationa...
# 6011   [methodology, visualize, interpret, classifica...
# 30612  [recognition, conditions, important, challengi...
# 30656  [newtonian, mechanics, understood, explaining,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10687    [nonparametric, approaches, clustering, inform...
# 39282    [interaction, capability, different, different...
# 16687    [introduces, recognition, coreference, resolut...
# 22817    [algorithm, stochastic, distributions, probabi...
# 5198     [graphical, algorithm, structure, undirected, ...
#                                ...
# 18816    [classifications, computational, complexity, r...
# 31067    [tremendous, multimedia, representation, utili...
# 3319     [selection, important, components, classificat...
# 5187     [compressive, measurements, extremely, structu...
# 37983    [independent, averaging, algorithm, combinatio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8803 words.
# Out of those 4535 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="92516860-8d65-4760-a623-adc7ee6ba6a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92516860-8d65-4760-a623-adc7ee6ba6a9")) {                    Plotly.newPlot(                        "92516860-8d65-4760-a623-adc7ee6ba6a9",                        [{"x":["complexity","information","dependent","introduced","representation","approaches","parameters","unsupervised","flexibility","dirichlet","correspondence","efficient","advantage","illustrate","clustering","distribution","statistics","application","extensions","additional","introduce","nonparametric","contributions","retrieval","recognition","trajectories","functions","similarity","significantly","performed","representations","comprehensive","architecture","capability","interaction","experimental","different","motivated","developed","processed","resolution","introduces","including","contribution","corresponding","techniques","specifically","considered","outperforms","coreference","consisting","applicable","wikipedia","traditional","adjusting","structures","specified","iteratively","amortized","autoencoder","inference","adaptively","maximally","architectures","demonstrate","direction","applications","variational","differentiable","parameter","decreases","divergence","algorithm","stochastic","probabilistic","unnormalized","expressive","distributions","convergence","undirected","estimation","penalized","particular","graphical","outperform","regularization","coordinate","occasionally","efficiently","estimated","equations","precision","structure","algorithms","covariance","likelihood","optimization","alternatives","converged","following","stationary","partition","distinguished","propagation","connections","marginals","arbitrary","structured","deviations","conditions","approximations","combinations","properties","described","exponential","reparameterization","approximate","desirable","treewidth","minimizing","important","wainwright","crowdsourcing","experience","exploring","attracted","simulated","estimates","respectively","performance","detection","theoretical","nonconvex","therefore","principle","statistically","evaluation","knowledge","attention","procedures","iterative","assessment","methodology","crowdsourced","simulations","discovery","facilitated","accomplished","discovered","interesting","predicting","transactions","discovering","membership","generative","clusterings","transactional","extracted","relations","comparing","characterized","synthetic","remaining","qualitatively","structuring","clinically","enhancement","quantitatively","modelling","multiscale","junctions","morphology","essential","retinopathy","diagnosis","quantification","segmentation","transform","mathematical","attractive","completeness","continuous","typically","accompanying","semantics","technique","describes","tractable","respected","observation","effectiveness","surprisingly","crucially","regression","significant","molecular","challenges","arithmetic","successful","expressions"],"y":[249,643,84,126,363,423,242,154,42,22,28,398,76,57,141,209,51,233,34,122,313,18,37,124,393,37,220,140,285,143,257,67,233,52,95,398,762,68,209,40,116,79,255,63,138,389,190,134,254,5,56,44,19,176,8,137,34,23,2,25,199,25,11,133,576,64,420,45,19,139,11,29,821,134,172,2,32,110,131,16,218,7,285,48,79,92,17,3,162,59,32,95,372,592,19,58,290,26,2,78,21,32,7,66,52,7,89,105,7,118,34,42,212,71,53,3,119,29,4,42,363,1,17,45,39,24,68,76,83,894,322,166,16,152,58,18,257,354,163,46,90,43,61,6,46,57,5,8,27,65,85,3,22,11,113,4,2,118,80,75,28,141,18,24,5,10,32,30,58,12,2,10,76,2,56,12,173,75,57,16,12,111,114,5,93,260,86,26,2,65,207,30,7,121,250,7,121,8,63,36],"type":"bar"},{"x":["complexity","information","dependent","introduced","representation","approaches ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4535,), (4535, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Multiclass</span> <span style=''>Weighted</span> <span style=''>Loss</span> <span style=''>for</span> <span style=''>Instance</span> <span style='background-color:rgba(0, 255, 0, 0.6714975845410628);'>Segmentation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>Cluttered</span> <span style=''>Cells</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multiclass</span> <span style=''>weighted</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>for</span> <span style=''>instance</span> <span style='background-color:rgba(0, 255, 0, 0.6714975845410628);'>segmentation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>cluttered</span> <span style=''>cells</span> <span style=''>We</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>primarily</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>need</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>developmental</span> <span style=''>biologists</span> <span style=''>to</span> <span style=''>quantify</span> <span style=''>and</span> <span style=''>model</span> <span style=''>the</span> <span style=''>behavior</span> <span style=''>of</span> <span style=''>blood</span> <span style=''>T</span> <span style=''>cells</span> <span style=''>which</span> <span style=''>might</span> <span style=''>help</span> <span style=''>us</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3656387665198237);'>understanding</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999986);'>regulation</span> <span style='background-color:rgba(0, 255, 0, 0.4482758620689654);'>mechanisms</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ultimately</span> <span style=''>help</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>researchers</span> <span style=''>in</span> <span style=''>their</span> <span style=''>quest</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.42553191489361697);'>developing</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effective</span> <span style=''>immuno</span> <span style=''>therapy</span> <span style=''>cancer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>treatment</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857142);'>Segmenting</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individual</span> <span style=''>touching</span> <span style=''>cells</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.8333333333333333);'>cluttered</span> <span style=''>regions</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.4447439353099731);'>challenging</span> <span style=''>as</span> <span style=''>the</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>on</span> <span style=''>shared</span> <span style=''>borders</span> <span style=''>and</span> <span style=''>cell</span> <span style='background-color:rgba(0, 255, 0, 0.7647058823529411);'>foreground</span> <span style=''>are</span> <span style=''>similar</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>difficulting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminating</span> <span style=''>pixels</span> <span style=''>into</span> <span style=''>proper</span> <span style=''>classes</span> <span style=''>We</span> <span style=''>present</span> <span style=''>two</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Piecewise</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximation</span> <span style=''>for</span> <span style=''>Feature</span> <span style=''>Subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Sequential</span> <span style=''>Logit</span> <span style=''>Model</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>concerns</span> <span style=''>a</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selecting</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>features</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>logit</span> <span style=''>model</span> <span style=''>Tanaka</span> <span style=''>and</span> <span style=''>Nakagawa</span> <span style=''>(2014)</span> <span style=''>proposed</span> <span style=''>a</span> <span style=''>mixed</span> <span style=''>integer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>logistic</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>However</span> <span style=''>since</span> <span style=''>there</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>gap</span> <span style=''>between</span> <span style=''>the</span> <span style=''>logistic</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>and</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>may</span> <span style=''>fail</span> <span style=''>to</span> <span style=''>find</span> <span style=''>a</span> <span style=''>good</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>features</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>this</span> <span style=''>drawback</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>piecewise</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>to</span> <span style=''>the</span> <span style=''>logistic</span> <span style=''>loss</span> <span style=''>function</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Accordingly</span> <span style=''>we</span> <span style=''>frame</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>subset</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimizing</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>criterion</span> <span style=''>as</span> <span style=''>a</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>LMS</span> <span style=''>via</span> <span style=''>Online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Linearized</span> <span style=''>Bregman</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Iteration</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>version</span> <span style=''>of</span> <span style=''>least</span> <span style=''>mean</span> <span style=''>square</span> <span style=''>(LMS)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>sparse</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identification</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>linearized</span> <span style=''>Bregman</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>(OLBI)</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cumulative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>error</span> <span style=''>squared</span> <span style=''>along</span> <span style=''>with</span> <span style=''>an</span> <span style=''>l1</span> <span style=''>l2</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>By</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>systematically</span> <span style=''>treating</span> <span style=''>the</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>we</span> <span style=''>arrive</span> <span style=''>at</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>two</span> <span style=''>step</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iteration</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>OLBI</span> <span style=''>is</span> <span style=''>bias</span> <span style=''>free</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>operation</span> <span style=''>with</span> <span style=''>existing</span> <span style=''>sparse</span> <span style=''>LMS</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>by</span> <span style=''>rederiving</span> <span style=''>them</span> <span style=''>in</span> <span style=''>the</span> <span style=''>online</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>We</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergence</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>OLBI</span> <span style=''>for</span> <span style=''>white</span> <span style=''>input</span> <span style=''>signals</span> <span style=''>and</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.35849056603773577);'>expressions</span> <span style=''>for</span> <span style=''>both</span> <span style=''>the</span> <span style=''>steady</span> <span style=''>state</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>instantaneous</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style=''>Metrics</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigates</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>foundations</span> <span style=''>of</span> <span style=''>metric</span> <span style=''>learning</span> <span style=''>focused</span> <span style=''>on</span> <span style=''>three</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>that</span> <span style=''>are</span> <span style=''>not</span> <span style=''>fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addressed</span> <span style=''>in</span> <span style=''>prior</span> <span style=''>work</span> <span style=''>1)</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>learning</span> <span style=''>general</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>(low</span> <span style=''>rank)</span> <span style=''>metrics</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>sparse</span> <span style=''>metrics</span> <span style=''>2)</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>upper</span> <span style=''>and</span> <span style=''>lower</span> <span style=''>(minimax)bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>error</span> <span style=''>3)</span> <span style=''>we</span> <span style=''>quantify</span> <span style=''>the</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>metric</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style=''>the</span> <span style=''>feature</span> <span style=''>space</span> <span style=''>and</span> <span style=''>the</span> <span style=''>dimensionrank</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>metric4)</span> <span style=''>we</span> <span style=''>also</span> <span style=''>bound</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learned</span> <span style=''>metric</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>true</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>metric</span> <span style=''>All</span> <span style=''>the</span> <span style=''>results</span> <span style=''>involve</span> <span style=''>novel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>mathematical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>the</span> <span style=''>metric</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>lso</span> <span style=''>shed</span> <span style=''>new</span> <span style=''>light</span> <span style=''>on</span> <span style=''>the</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>ordinal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>(aka</span> <span style=''>non</span> <span styl ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	segmentation (0.06167557932263815)
# 	processing (0.10231729055258466)
# 	representation (0.12941176470588237)
# 	architecture (0.08306595365418895)
# 	knowledge (0.12620320855614972)
# 	experimental (0.14188948306595364)
# 	detection (0.11479500891265597)
# 	convolutional (0.13832442067736186)
# 	different (0.2716577540106952)
# 	recognition (0.14010695187165775)
#
# Some Statistics words are:
# 	variational (0.0987468671679198)
# 	stochastic (0.13082706766917293)
# 	theoretical (0.1468671679197995)
# 	estimation (0.1699248120300752)
# 	algorithm (0.3969924812030075)
# 	distribution (0.18045112781954886)
# 	statistical (0.15288220551378445)
# 	dimensional (0.1849624060150376)
# 	inference (0.2)
# 	regression (0.18546365914786966)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ebece76b-3f9a-4ae8-b72e-3933acd0fa1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ebece76b-3f9a-4ae8-b72e-3933acd0fa1a")) {                    Plotly.newPlot(                        "ebece76b-3f9a-4ae8-b72e-3933acd0fa1a",                        [{"x":["complexity","information","dependent","introduced","representation","approaches","parameters","unsupervised","flexibility","dirichlet","correspondence","efficient","advantage","illustrate","clustering","distribution","statistics","application","extensions","additional","introduce","nonparametric","contributions","retrieval","recognition","trajectories","functions","similarity","significantly","performed","representations","comprehensive","architecture","capability","interaction","experimental","different","motivated","developed","processed","resolution","introduces","including","contribution","corresponding","techniques","specifically","considered","outperforms","coreference","consisting","applicable","wikipedia","traditional","adjusting","structures","specified","iteratively","amortized","autoencoder","inference","adaptively","maximally","architectures","demonstrate","direction","applications","variational","differentiable","parameter","decreases","divergence","algorithm","stochastic","probabilistic","unnormalized","expressive","distributions","convergence","undirected","estimation","penalized","particular","graphical","outperform","regularization","coordinate","occasionally","efficiently","estimated","equations","precision","structure","algorithms","covariance","likelihood","optimization","alternatives","converged","following","stationary","partition","distinguished","propagation","connections","marginals","arbitrary","structured","deviations","conditions","approximations","combinations","properties","described","exponential","reparameterization","approximate","desirable","treewidth","minimizing","important","wainwright","crowdsourcing","experience","exploring","attracted","simulated","estimates","respectively","performance","detection","theoretical","nonconvex","therefore","principle","statistically","evaluation","knowledge","attention","procedures","iterative","assessment","methodology","crowdsourced","simulations","discovery","facilitated","accomplished","discovered","interesting","predicting","transactions","discovering","membership","generative","clusterings","transactional","extracted","relations","comparing","characterized","synthetic","remaining","qualitatively","structuring","clinically","enhancement","quantitatively","modelling","multiscale","junctions","morphology","essential","retinopathy","diagnosis","quantification","segmentation","transform","mathematical","attractive","completeness","continuous","typically","accompanying","semantics","technique","describes","tractable","respected","observation","effectiveness","surprisingly","crucially","regression","significant","molecular","challenges","arithmetic","successful","expressions","represented","frequently","generated","synthesis","modification","considerable","technical","recursion","framework","quadratic","reinforcement","importance","formulation","variables","parallelized","processes","marginalization","resulting","compression","supervised","consuming","furthermore","applicability","conducted","performances","improving","resonance","literature","manuscript","convolutional","denoising","parliament","principal","background","collected","government","parliamentary","positions","downloaded","affiliations","accumulated","artificial","intelligence","predictions","accumulates","simulator","conventional","effective","accurately","procedurally","schedules","unresolved","smoothness","observations","nonlinear","reparametrizati ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	reparametrization
# 	presenceabsence
# 	retailers
# 	catalogue
# 	concordance
# 	transcriptional
# 	certainly
# 	ergodicity
# 	microbial
# 	spectrometry
# 	infectious
# 	phenotypes
# 	marginalised
# 	gracefully
# 	underestimation
# 	safeguard
# 	emphmulti
# 	spectroradiometer
# 	memberships
# 	actigraphy
# Some words which never appear in Statistics papers:
# 	coreference
# 	treewidth
# 	junctions
# 	retinopathy
# 	parliament
# 	parliamentary
# 	procedurally
# 	undetected
# 	decidability
# 	solvability
# 	dermoscopic
# 	pedestrian
# 	illuminating
# 	attenuation
# 	millimeter
# 	homography
# 	concurrent
# 	prototyping
# 	affordance
# 	affordances

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068896731624981e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
